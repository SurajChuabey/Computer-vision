# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
import keras # you can import keras as well
print("Keras version:", keras.__version__) # This will print the Keras version bundled with TF
# Out:
# TensorFlow version: 2.13.1
# Keras version: 2.13.1

# %%
import tensorflow as tf
import cv2
import numpy as np
label=['closedFist', 'multiFingerBend', 'openPalm', 'singleFingerBend']

# Load the model
model = tf.keras.models.load_model('gesture_recogniser.keras')

# Webcam setup
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Cannot open webcam")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

    # Preprocess the frame (same as in your single image code):
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Color conversion is important
    img = cv2.resize(img, (256, 256))
    img = np.expand_dims(img, axis=0)
    img = img / 255.0

    # Make predictions:
    predictions = model.predict(img)
    predicted_label = np.argmax(predictions, axis=1)[0]
    predicted_label = label[predicted_label]  # Use your label mapping
    probability = np.max(predictions, axis=1)[0]

    # Display results on the frame:
    label_text = f"Label: {predicted_label} | Prob: {probability:.2f}"

    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 0.5  # Adjust as needed
    font_thickness = 2
    text_size = cv2.getTextSize(label_text, font, font_scale, font_thickness)[0]

    text_x = 10  # X position
    text_y = 30  # Y position

    cv2.putText(frame, label_text, (text_x, text_y), font, font_scale, (0, 255, 0), font_thickness, cv2.LINE_AA) # Green color

    cv2.imshow('Webcam Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import tensorflow as tf
import cv2
import numpy as np
label=['closedFist', 'multiFingerBend', 'openPalm', 'singleFingerBend']

# Function to preprocess the image (you may need to adjust based on your model's requirements)
def preprocess_image(image_path, target_size=(256, 256)):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, target_size)
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    image = image / 255.0  # Normalize image if required
    return image

# Prediction function
def predict_single_image(image_path, model):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    print(predictions)
    predicted_label = np.argmax(predictions, axis=1)[0]
    predicted_label=label[predicted_label]
    probability = np.max(predictions, axis=1)[0]
    return predicted_label, probability

# Load the model
model = tf.keras.models.load_model('gesture_recogniser.keras')

# Image path
image_path = "close_fist.jpeg"  # Replace with your image path

# Get prediction
predicted_label, probability = predict_single_image(image_path, model)

# Read the image again to display it
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Define the label and probability to display
label_text = f"Label: {predicted_label} | Prob: {probability:.2f}"

# Set font and size
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 0.3  # Adjust font scale to make it fit
font_thickness = 1
text_size = cv2.getTextSize(label_text, font, font_scale, font_thickness)[0]

# Calculate text position (top-left corner)
text_x = 1  # X position
text_y = 30  # Y position (ensure it's not too close to the edge)

# Add the label and probability to the image
cv2.putText(image, label_text, (text_x, text_y), font, font_scale, (255, 0, 0), font_thickness, cv2.LINE_AA)

# Display the image with the label
cv2.imshow("res",image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 118ms/step
# [[3.92240928e-21 1.00829735e-11 9.99998450e-01 1.58998296e-06]]

# %%
import cv2
import torch
import numpy as np
from ultralytics import YOLO

# Load YOLO model
model = YOLO("yolov8x.pt")

# Open video file
cap = cv2.VideoCapture("/home/suraj/PlayGround/myprograms/240335.mp4")

# Define target classes for detection
target_classes = ['car', 'bus', 'truck', 'person']

# Polygon points for ROI
pts = []
roi_set = False  # Flag to check if ROI is set

count = 0
number_of_photos = 3

# Function to draw ROI polygon
def draw_polygon(event, x, y, flags, param):
    global pts, roi_set
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x, y)
        pts.append((x, y))
    elif event == cv2.EVENT_RBUTTONDOWN:  # Right-click to clear polygon
        pts = []
        roi_set = False  # Reset ROI flag
    if len(pts) >= 4 and not roi_set:  # Once polygon is complete
        roi_set = True

# Function to check if a point is inside the polygon
def inside_polygon(point, polygon):
    return cv2.pointPolygonTest(np.array(polygon, np.int32), (point[0], point[1]), False) >= 0

# Register mouse callback
cv2.namedWindow('Video')
cv2.setMouseCallback('Video', draw_polygon)

# Preprocess function for YOLO model
def preprocess(img):
    height, width = img.shape[:2]
    ratio = height / width
    return cv2.resize(img, (640, int(640 * ratio)))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_detected = frame.copy()
    frame = preprocess(frame)
    
    # Run YOLO detection
    results = model(frame)

    for result in results:
        for box in result.boxes:
            cls = int(box.cls[0])
            name = model.names[cls]

            if name in target_classes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                center_x = (x1 + x2) // 2
                center_y = (y1 + y2) // 2

                # Draw bounding box and labels
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 255, 0), 3)
                cv2.putText(frame, name, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)
                cv2.circle(frame, (center_x, center_y), 5, (0, 0, 255), -1)

                # Draw polygon ROI if set
                if roi_set:
                    frame_copy = frame.copy()
                    cv2.fillPoly(frame_copy, [np.array(pts)], (0, 255, 0))
                    frame = cv2.addWeighted(frame_copy, 0.2, frame, 0.8, 0)

                    # Check if person is inside polygon
                    if inside_polygon((center_x, center_y), pts) and name in target_classes:
                        mask = np.zeros_like(frame_detected)
                        points = np.array([[x1, y1], [x1, y2], [x2, y2], [x2, y1]])
                        mask = cv2.fillPoly(mask, [points], (255, 255, 255))
                        frame_detected = cv2.bitwise_and(frame_detected, mask)

                        # # Save detected image
                        # if count < number_of_photos:
                        #     cv2.imwrite(f"Detected Photos/detected_{count}.jpg", frame_detected)
                        #     count += 1

                        # Display warning text
                        cv2.putText(frame, "Target", (center_x, center_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                        cv2.putText(frame, "Person Detected!", (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 3)

    cv2.imshow("Video", frame)

    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):  # Press 'q' to exit
        break
    elif key == ord('c'):  # Press 'c' to clear the polygon
        pts.clear()
        roi_set = False

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### With time and movement detection

# %%
import cv2
import torch
import numpy as np
import time
from ultralytics import YOLO

# Load YOLO model
model = YOLO("yolov8n.pt")

# Open video file
cap = cv2.VideoCapture(0)

# Define target classes for detection
target_classes = ['car', 'bus', 'truck', 'person']

# Polygon points for ROI
pts = []
roi_set = False  # Flag to check if ROI is set
count = 0
number_of_photos = 3

# Tracking person position and time
person_in_roi = False
last_position = None
time_in_roi = 0  # In seconds
movement_threshold = 100  # Threshold for movement (in pixels)
time_threshold = 10  # Time threshold for alert (in seconds)

# Function to draw ROI polygon
def draw_polygon(event, x, y, flags, param):
    global pts, roi_set
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x, y)
        pts.append((x, y))
    elif event == cv2.EVENT_RBUTTONDOWN:  # Right-click to clear polygon
        pts = []
        roi_set = False  # Reset ROI flag
    if len(pts) >= 4 and not roi_set:  # Once polygon is complete
        roi_set = True

# Function to check if a point is inside the polygon
def inside_polygon(point, polygon):
    return cv2.pointPolygonTest(np.array(polygon, np.int32), (point[0], point[1]), False) >= 0

# Register mouse callback
cv2.namedWindow('Video')
cv2.setMouseCallback('Video', draw_polygon)

# Preprocess function for YOLO model
def preprocess(img):
    height, width = img.shape[:2]
    ratio = height / width
    return cv2.resize(img, (640, int(640 * ratio)))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_detected = frame.copy()
    frame = preprocess(frame)
    
    # Run YOLO detection
    results = model(frame)

    for result in results:
        for box in result.boxes:
            cls = int(box.cls[0])
            name = model.names[cls]

            if name in target_classes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                center_x = (x1 + x2) // 2
                center_y = (y1 + y2) // 2

                # Draw bounding box and labels
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 255, 0), 3)
                cv2.putText(frame, name, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)
                cv2.circle(frame, (center_x, center_y), 5, (0, 0, 255), -1)

                # Draw polygon ROI if set
                if roi_set:
                    frame_copy = frame.copy()
                    cv2.fillPoly(frame_copy, [np.array(pts)], (0, 255, 0))
                    frame = cv2.addWeighted(frame_copy, 0.2, frame, 0.8, 0)

                    # Check if person is inside polygon
                    if inside_polygon((center_x, center_y), pts) and name == 'person':
                        mask = np.zeros_like(frame_detected)
                        points = np.array([[x1, y1], [x1, y2], [x2, y2], [x2, y1]])
                        mask = cv2.fillPoly(mask, [points], (255, 255, 255))
                        frame_detected = cv2.bitwise_and(frame_detected, mask)

                        # Save detected image
                        if count < number_of_photos:
                            cv2.imwrite(f"Detected Photos/detected_{count}.jpg", frame_detected)
                            count += 1

                        # Display warning text
                        cv2.putText(frame, "Target", (center_x, center_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                        cv2.putText(frame, "Person Detected!", (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 3)

                        # Check if the person has been in the ROI without moving
                        if last_position is None:
                            last_position = (center_x, center_y)
                            time_in_roi = time.time()  # Start timer when person enters ROI
                        else:
                            # Check if person is moving
                            distance = np.linalg.norm(np.array([center_x, center_y]) - np.array(last_position))
                            if distance < movement_threshold:  # If the movement is minimal
                                # Calculate how long the person has been stationary in the ROI
                                if time.time() - time_in_roi >= time_threshold:
                                    cv2.putText(frame, "ALERT: Person not moving!", (20, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                            else:
                                # If moving, reset the timer
                                time_in_roi = time.time()

                            last_position = (center_x, center_y)  # Update last position

    cv2.imshow("Video", frame)

    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):  # Press 'q' to exit
        break
    elif key == ord('c'):  # Press 'c' to clear the polygon
        pts.clear()
        roi_set = False
        last_position = None
        time_in_roi = 0

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 persons, 136.6ms
# Speed: 5.6ms preprocess, 136.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 150.1ms
# Speed: 6.7ms preprocess, 150.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 177.6ms
# Speed: 6.1ms preprocess, 177.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 253.1ms
# Speed: 3.9ms preprocess, 253.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 134.3ms
# Speed: 6.5ms preprocess, 134.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 110.9ms
# Speed: 3.3ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.9ms
# Speed: 2.3ms preprocess, 89.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.5ms
# Speed: 2.4ms preprocess, 86.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 96.5ms
# Speed: 1.7ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.2ms
# Speed: 1.6ms preprocess, 89.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.9ms
# Speed: 2.5ms preprocess, 83.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 86.4ms
# Speed: 4.4ms preprocess, 86.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.2ms
# Speed: 2.9ms preprocess, 84.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.0ms
# Speed: 2.1ms preprocess, 84.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.8ms
# Speed: 11.1ms preprocess, 84.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 82.2ms
# Speed: 2.2ms preprocess, 82.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.4ms
# Speed: 1.8ms preprocess, 88.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.4ms
# Speed: 1.6ms preprocess, 83.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 90.9ms
# Speed: 1.8ms preprocess, 90.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 83.3ms
# Speed: 1.6ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 laptop, 86.3ms
# Speed: 2.1ms preprocess, 86.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 86.2ms
# Speed: 1.9ms preprocess, 86.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 87.8ms
# Speed: 1.7ms preprocess, 87.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 2 laptops, 81.1ms
# Speed: 2.5ms preprocess, 81.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 82.7ms
# Speed: 2.3ms preprocess, 82.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 laptop, 86.2ms
# Speed: 1.7ms preprocess, 86.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 81.9ms
# Speed: 1.7ms preprocess, 81.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 85.1ms
# Speed: 1.7ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 81.9ms
# Speed: 2.9ms preprocess, 81.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 87.4ms
# Speed: 2.0ms preprocess, 87.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 82.4ms
# Speed: 1.6ms preprocess, 82.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.8ms
# Speed: 1.7ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.6ms
# Speed: 2.3ms preprocess, 83.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 82.7ms
# Speed: 2.3ms preprocess, 82.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 82.8ms
# Speed: 2.0ms preprocess, 82.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 84.2ms
# Speed: 2.3ms preprocess, 84.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 87.2ms
# Speed: 3.0ms preprocess, 87.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 86.8ms
# Speed: 1.5ms preprocess, 86.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.2ms
# Speed: 1.9ms preprocess, 80.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 88.0ms
# Speed: 2.8ms preprocess, 88.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 84.5ms
# Speed: 1.9ms preprocess, 84.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 90.8ms
# Speed: 2.4ms preprocess, 90.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 94.0ms
# Speed: 1.7ms preprocess, 94.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 88.9ms
# Speed: 2.6ms preprocess, 88.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 87.6ms
# Speed: 2.0ms preprocess, 87.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 83.4ms
# Speed: 4.6ms preprocess, 83.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 88.8ms
# Speed: 1.6ms preprocess, 88.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 88.3ms
# Speed: 1.7ms preprocess, 88.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 86.9ms
# Speed: 2.0ms preprocess, 86.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 82.5ms
# Speed: 2.3ms preprocess, 82.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 laptop, 84.1ms
# Speed: 1.8ms preprocess, 84.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 laptop, 89.6ms
# Speed: 1.9ms preprocess, 89.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 91.5ms
# Speed: 2.2ms preprocess, 91.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 84.2ms
# Speed: 1.8ms preprocess, 84.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 laptop, 82.4ms
# Speed: 1.6ms preprocess, 82.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 1 laptop, 82.9ms
# Speed: 1.5ms preprocess, 82.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 85.4ms
# Speed: 2.0ms preprocess, 85.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 80.9ms
# Speed: 1.6ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 79.8ms
# Speed: 2.0ms preprocess, 79.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 11 97
#
# 0: 480x640 2 persons, 2 chairs, 81.9ms
# Speed: 1.4ms preprocess, 81.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 83.2ms
# Speed: 1.6ms preprocess, 83.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 82.6ms
# Speed: 1.6ms preprocess, 82.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 1 laptop, 89.8ms
# Speed: 2.2ms preprocess, 89.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 90.5ms
# Speed: 2.1ms preprocess, 90.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 1 laptop, 85.7ms
# Speed: 2.6ms preprocess, 85.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 1 laptop, 83.2ms
# Speed: 3.6ms preprocess, 83.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 192 95
#
# 0: 480x640 2 persons, 1 chair, 79.5ms
# Speed: 2.4ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 83.0ms
# Speed: 2.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 82.1ms
# Speed: 2.3ms preprocess, 82.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 82.3ms
# Speed: 2.7ms preprocess, 82.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 81.5ms
# Speed: 1.9ms preprocess, 81.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 75.8ms
# Speed: 1.5ms preprocess, 75.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 75.6ms
# Speed: 2.1ms preprocess, 75.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 75.4ms
# Speed: 1.4ms preprocess, 75.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 71.7ms
# Speed: 1.4ms preprocess, 71.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 76.6ms
# Speed: 1.5ms preprocess, 76.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 241 432
#
# 0: 480x640 2 persons, 3 chairs, 76.9ms
# Speed: 1.7ms preprocess, 76.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 76.8ms
# Speed: 1.5ms preprocess, 76.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 87.8ms
# Speed: 1.5ms preprocess, 87.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 83.2ms
# Speed: 1.5ms preprocess, 83.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 85.0ms
# Speed: 1.4ms preprocess, 85.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 86.2ms
# Speed: 2.0ms preprocess, 86.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 84.2ms
# Speed: 1.5ms preprocess, 84.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 84.5ms
# Speed: 2.9ms preprocess, 84.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 134.2ms
# Speed: 1.4ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 94.5ms
# Speed: 6.4ms preprocess, 94.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 88.3ms
# Speed: 2.6ms preprocess, 88.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 3 451
#
# 0: 480x640 2 persons, 2 chairs, 87.6ms
# Speed: 1.5ms preprocess, 87.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 90.0ms
# Speed: 1.5ms preprocess, 90.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 89.4ms
# Speed: 2.7ms preprocess, 89.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 86.9ms
# Speed: 2.7ms preprocess, 86.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 88.3ms
# Speed: 1.8ms preprocess, 88.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 89.4ms
# Speed: 1.6ms preprocess, 89.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 87.4ms
# Speed: 2.5ms preprocess, 87.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 81.6ms
# Speed: 3.1ms preprocess, 81.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 83.8ms
# Speed: 1.3ms preprocess, 83.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 88.4ms
# Speed: 1.3ms preprocess, 88.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 80.7ms
# Speed: 1.7ms preprocess, 80.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 85.5ms
# Speed: 2.3ms preprocess, 85.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 87.9ms
# Speed: 1.4ms preprocess, 87.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 90.9ms
# Speed: 2.5ms preprocess, 90.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 80.8ms
# Speed: 3.1ms preprocess, 80.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 83.9ms
# Speed: 2.5ms preprocess, 83.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 81.8ms
# Speed: 1.9ms preprocess, 81.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 1 refrigerator, 82.8ms
# Speed: 1.4ms preprocess, 82.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 1 refrigerator, 78.3ms
# Speed: 1.6ms preprocess, 78.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 1 refrigerator, 84.6ms
# Speed: 2.3ms preprocess, 84.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 5 chairs, 85.7ms
# Speed: 1.5ms preprocess, 85.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 86.7ms
# Speed: 1.7ms preprocess, 86.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 1 refrigerator, 85.6ms
# Speed: 1.3ms preprocess, 85.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 87.7ms
# Speed: 1.4ms preprocess, 87.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 86.2ms
# Speed: 1.4ms preprocess, 86.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 85.7ms
# Speed: 1.8ms preprocess, 85.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 91.7ms
# Speed: 1.5ms preprocess, 91.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 82.0ms
# Speed: 1.8ms preprocess, 82.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 85.8ms
# Speed: 2.4ms preprocess, 85.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 82.8ms
# Speed: 1.7ms preprocess, 82.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 83.4ms
# Speed: 2.8ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 88.8ms
# Speed: 2.0ms preprocess, 88.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 83.2ms
# Speed: 1.4ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 81.7ms
# Speed: 7.3ms preprocess, 81.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 86.4ms
# Speed: 1.9ms preprocess, 86.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 82.9ms
# Speed: 1.3ms preprocess, 82.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 82.9ms
# Speed: 1.3ms preprocess, 82.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 88.2ms
# Speed: 1.3ms preprocess, 88.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 83.7ms
# Speed: 1.4ms preprocess, 83.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 83.4ms
# Speed: 1.4ms preprocess, 83.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 137.2ms
# Speed: 4.4ms preprocess, 137.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 refrigerators, 96.5ms
# Speed: 5.8ms preprocess, 96.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 89.6ms
# Speed: 1.7ms preprocess, 89.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 93.1ms
# Speed: 1.8ms preprocess, 93.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 82.8ms
# Speed: 1.4ms preprocess, 82.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 87.3ms
# Speed: 1.6ms preprocess, 87.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 83.2ms
# Speed: 1.3ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 81.1ms
# Speed: 1.4ms preprocess, 81.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.1ms
# Speed: 1.4ms preprocess, 84.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 85.5ms
# Speed: 2.1ms preprocess, 85.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 92.4ms
# Speed: 1.6ms preprocess, 92.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 86.2ms
# Speed: 1.5ms preprocess, 86.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 85.7ms
# Speed: 1.9ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 88.6ms
# Speed: 2.1ms preprocess, 88.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 87.3ms
# Speed: 1.9ms preprocess, 87.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 97.2ms
# Speed: 2.4ms preprocess, 97.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 82.8ms
# Speed: 1.8ms preprocess, 82.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 95.4ms
# Speed: 1.8ms preprocess, 95.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 86.2ms
# Speed: 2.7ms preprocess, 86.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 94.1ms
# Speed: 1.6ms preprocess, 94.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 103.9ms
# Speed: 1.7ms preprocess, 103.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 81.5ms
# Speed: 1.4ms preprocess, 81.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 93.0ms
# Speed: 2.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 91.0ms
# Speed: 1.6ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 84.1ms
# Speed: 2.1ms preprocess, 84.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 90.9ms
# Speed: 1.8ms preprocess, 90.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 90.4ms
# Speed: 1.6ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 92.8ms
# Speed: 1.6ms preprocess, 92.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 80.0ms
# Speed: 1.5ms preprocess, 80.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 78.5ms
# Speed: 1.2ms preprocess, 78.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 83.8ms
# Speed: 1.4ms preprocess, 83.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.2ms
# Speed: 1.4ms preprocess, 83.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 87.7ms
# Speed: 1.9ms preprocess, 87.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 85.6ms
# Speed: 1.5ms preprocess, 85.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.9ms
# Speed: 1.7ms preprocess, 123.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 98.6ms
# Speed: 2.8ms preprocess, 98.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 87.1ms
# Speed: 1.3ms preprocess, 87.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.8ms
# Speed: 1.4ms preprocess, 80.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 95.2ms
# Speed: 1.5ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 89.4ms
# Speed: 2.8ms preprocess, 89.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 105.9ms
# Speed: 1.3ms preprocess, 105.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 92.7ms
# Speed: 1.4ms preprocess, 92.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 94.1ms
# Speed: 1.6ms preprocess, 94.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 83.2ms
# Speed: 2.0ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 94.7ms
# Speed: 1.8ms preprocess, 94.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 89.8ms
# Speed: 2.6ms preprocess, 89.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 82.9ms
# Speed: 1.8ms preprocess, 82.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.4ms
# Speed: 2.0ms preprocess, 84.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 87.6ms
# Speed: 1.9ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 91.8ms
# Speed: 1.6ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 88.8ms
# Speed: 1.4ms preprocess, 88.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 79.3ms
# Speed: 1.6ms preprocess, 79.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 85.6ms
# Speed: 1.6ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 96.4ms
# Speed: 1.7ms preprocess, 96.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 92.7ms
# Speed: 1.5ms preprocess, 92.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.8ms
# Speed: 1.9ms preprocess, 80.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 85.9ms
# Speed: 2.7ms preprocess, 85.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 89.3ms
# Speed: 1.9ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 94.5ms
# Speed: 1.7ms preprocess, 94.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 92.4ms
# Speed: 2.4ms preprocess, 92.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 86.7ms
# Speed: 1.7ms preprocess, 86.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 93.5ms
# Speed: 1.4ms preprocess, 93.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 82.5ms
# Speed: 1.6ms preprocess, 82.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 83.8ms
# Speed: 1.6ms preprocess, 83.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 95.5ms
# Speed: 1.5ms preprocess, 95.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 155.3ms
# Speed: 1.8ms preprocess, 155.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 81.1ms
# Speed: 1.9ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 83.7ms
# Speed: 2.2ms preprocess, 83.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 92.7ms
# Speed: 2.1ms preprocess, 92.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 85.8ms
# Speed: 3.7ms preprocess, 85.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 92.1ms
# Speed: 1.5ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 87.1ms
# Speed: 1.6ms preprocess, 87.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 87.0ms
# Speed: 2.7ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 90.2ms
# Speed: 1.6ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 87.5ms
# Speed: 1.6ms preprocess, 87.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 92.0ms
# Speed: 2.4ms preprocess, 92.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 84.6ms
# Speed: 1.6ms preprocess, 84.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 81.3ms
# Speed: 1.2ms preprocess, 81.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 87.0ms
# Speed: 2.4ms preprocess, 87.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 88.4ms
# Speed: 1.7ms preprocess, 88.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 86.9ms
# Speed: 1.6ms preprocess, 86.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 88.1ms
# Speed: 2.2ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 84.3ms
# Speed: 4.7ms preprocess, 84.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 94.0ms
# Speed: 1.6ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 88.4ms
# Speed: 1.9ms preprocess, 88.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 refrigerator, 89.7ms
# Speed: 1.7ms preprocess, 89.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 98.6ms
# Speed: 1.8ms preprocess, 98.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 90.3ms
# Speed: 1.5ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 90.9ms
# Speed: 2.5ms preprocess, 90.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 refrigerator, 89.9ms
# Speed: 1.8ms preprocess, 89.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 127.2ms
# Speed: 4.0ms preprocess, 127.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 87.1ms
# Speed: 3.3ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 90.0ms
# Speed: 1.6ms preprocess, 90.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 85.3ms
# Speed: 1.8ms preprocess, 85.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 82.3ms
# Speed: 1.4ms preprocess, 82.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 84.1ms
# Speed: 2.5ms preprocess, 84.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 86.3ms
# Speed: 1.7ms preprocess, 86.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 89.0ms
# Speed: 1.8ms preprocess, 89.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 86.8ms
# Speed: 1.7ms preprocess, 86.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 88.7ms
# Speed: 1.6ms preprocess, 88.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 80.9ms
# Speed: 1.2ms preprocess, 80.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 89.4ms
# Speed: 3.6ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 88.7ms
# Speed: 1.5ms preprocess, 88.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 83.2ms
# Speed: 1.9ms preprocess, 83.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 86.4ms
# Speed: 1.6ms preprocess, 86.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 84.8ms
# Speed: 1.8ms preprocess, 84.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 87.9ms
# Speed: 2.8ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 90.7ms
# Speed: 2.2ms preprocess, 90.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 84.6ms
# Speed: 1.4ms preprocess, 84.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 151.4ms
# Speed: 2.3ms preprocess, 151.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 86.8ms
# Speed: 1.5ms preprocess, 86.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 88.2ms
# Speed: 4.3ms preprocess, 88.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 89.9ms
# Speed: 2.4ms preprocess, 89.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 83.8ms
# Speed: 1.5ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 84.9ms
# Speed: 1.9ms preprocess, 84.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 90.7ms
# Speed: 1.9ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 83.7ms
# Speed: 2.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 80.7ms
# Speed: 1.5ms preprocess, 80.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 84.0ms
# Speed: 1.6ms preprocess, 84.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 87.6ms
# Speed: 2.7ms preprocess, 87.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.2ms
# Speed: 2.5ms preprocess, 83.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 89.2ms
# Speed: 1.8ms preprocess, 89.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.8ms
# Speed: 2.4ms preprocess, 86.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.3ms
# Speed: 1.6ms preprocess, 80.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.8ms
# Speed: 2.4ms preprocess, 81.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.8ms
# Speed: 1.9ms preprocess, 79.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.2ms
# Speed: 1.9ms preprocess, 80.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 85.3ms
# Speed: 2.2ms preprocess, 85.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 83.3ms
# Speed: 1.8ms preprocess, 83.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 84.6ms
# Speed: 2.2ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 88.3ms
# Speed: 1.8ms preprocess, 88.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.1ms
# Speed: 1.5ms preprocess, 79.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.9ms
# Speed: 3.9ms preprocess, 83.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.5ms
# Speed: 1.6ms preprocess, 134.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.9ms
# Speed: 4.5ms preprocess, 84.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 87.8ms
# Speed: 2.1ms preprocess, 87.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.5ms
# Speed: 2.4ms preprocess, 87.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 86.8ms
# Speed: 1.4ms preprocess, 86.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.3ms
# Speed: 1.8ms preprocess, 81.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 87.9ms
# Speed: 2.4ms preprocess, 87.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 83.0ms
# Speed: 2.6ms preprocess, 83.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 1 refrigerator, 81.9ms
# Speed: 1.7ms preprocess, 81.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.1ms
# Speed: 1.5ms preprocess, 80.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.8ms
# Speed: 1.7ms preprocess, 84.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 88.9ms
# Speed: 1.7ms preprocess, 88.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 91.0ms
# Speed: 1.6ms preprocess, 91.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 81.8ms
# Speed: 1.6ms preprocess, 81.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 85.5ms
# Speed: 2.3ms preprocess, 85.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 83.2ms
# Speed: 1.8ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 81.6ms
# Speed: 2.0ms preprocess, 81.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 85.4ms
# Speed: 1.7ms preprocess, 85.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 79.3ms
# Speed: 2.4ms preprocess, 79.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 86.5ms
# Speed: 3.3ms preprocess, 86.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 148.1ms
# Speed: 2.2ms preprocess, 148.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 85.0ms
# Speed: 1.9ms preprocess, 85.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 80.6ms
# Speed: 1.3ms preprocess, 80.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 84.3ms
# Speed: 2.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 82.0ms
# Speed: 4.4ms preprocess, 82.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 refrigerator, 86.5ms
# Speed: 2.1ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
